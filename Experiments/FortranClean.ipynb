# %%
import os
import sys
sys.path.append('./fortran')
import gibbsSampler6th
print gibbsSampler6th.gibbs_sampler.gibbssampler.__doc__
import numpy as np
import scipy as sp
from scipy.special import gammaln
import scipy.misc
import random
import os
import glob
import random
random.seed(1234)
#
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.special import gammaln

def index_sample(p):
    """
    Desc: Samples from n topics distributed multinomially and returns topic number
    input: p - A one dimensional array of float64 type that contains the probability for each topic
    output: an Integer specifying which topic was chosen from a multinomial distribution
    """
    r = random.random()
    for i in range(len(p)):
        r = r - p[i]
        if r < 0:
            return i
    return len(p) - 1

def word_indices(vec):
    """
    Desc: Take a vector of word counts from a document and create a generator for word indices
    input: A vector from a Document Term Frequency matrix for one document.
    output: A generator object to store the word indices when called
    """
    for idx in vec.nonzero()[0]:
        for i in xrange(int(vec[idx])):
            yield idx

def log_multi_beta(alpha, K = None):
    """
    Desc: Compute the logarithm of the multinomial beta function
    input: alpha - A vector with type float64 or a scaler of float64
           K - An integer that, if alpha is a scalar, multiplies the log by K
    output: a float64 with value of the logarithm of the multinomial beta
    """

    if K is None:
        return np.sum(gammaln(alpha) - gammaln(np.sum(alpha)))
    else:
        return K * gammaln(alpha) - gammaln(K * alpha)

class LdaSampler(object):

    def __init__(self,  data, ntopics, alpha = .1, beta = .1):
        """
        Desc: Initialize values for our class object
        alpha: a float scalar
        beta: a float scalar
        ntopics: an integer for the number of topics
        """
        #if not isinstance(alpha, float):
        #    raise Exception(" Initial value for alpha must be a floating point number (.3)")

        #if not isinstance(beta, float):
        #    raise Exception(" Initial value for beta must be a floating point number (.3)")

        #if not isinstance(ntopics, int):
        #    raise Exception(" The number of topics must be an integer")

        self.matrix = data
        self.ntopics = ntopics
        self.alpha = alpha
        self.beta = beta
        self._initialize()
    def _initialize(self):
        """
        Initialize:
        NZM: size(#Docs X #Topics) numpy array with type float 64
            The number of times document M and topic Z interact

        NZW: size(#Topics X #Words) numpy array with type float64
            The number of times topic Z and word W interact

        NM:  size(#Docs) numpy array with type float64
            Sum of documents occurances by topic and word

        NZ:  size(#Topics) numpy array with type float64
            Sum of Topic occurences by word and document

        Topics: size(?) An empty set
           Will come back to this
        """
        ndocs, vsize = self.matrix.shape

        self.NZM = np.zeros((ndocs, self.ntopics))
        self.NZW = np.zeros((self.ntopics, vsize))
        self.NM  = np.zeros(ndocs)
        self.NZ  = np.zeros(self.ntopics)
        self.topics = []
        self.logL = []
        
        for m in xrange(ndocs):
            # Iterates over i, doc_length - 1, and w, the size of unique_words - 1
            for n in xrange(vsize):
                if self.matrix[m,n] == 0:
                    continue
                for w in xrange(self.matrix[m,n]):
                # Initialize a random topic for each word
                    z = np.random.randint(self.ntopics)
                    self.topics.append(z)
                    self.NZM[m,z] += 1
                # Why is NM being +1'd for each i,w?
                    self.NM[m] += 1
                    self.NZW[z,n] += 1
                    self.NZ[z] += 1
                # Keep document, iterator for word, word index, and assignment
                #self.topics.append([i,w,z])
        
        self.topics = np.vstack(self.topics)
    def _conditional_distribution(self, m, n):
        """
        Desc: Compute the conditional distribution of words in document and topic
        Input: m: An integer representing the column index of the document
               w: The generator object from word_indices

        Output: p_z: An array size(1 X ntopics) containing
                  probabilities for topics of word
        
        The formula is:
        ((n_{k,-i}^(t) + \beta_t)/\sum_{t=1}^V(n_{k,-i}^(t) + \beta_t)) *
        ((n_{m,-i}^(t) + \alpha_k)/(\sum_{k=1}^K(n_m^k + \alpha_k) - 1))
        """
        vsize = self.matrix[m,:].nonzero()[0].size
        p_z = np.zeros(self.ntopics)
        for ii in xrange(self.ntopics):
            p_z[ii] = (self.NZM[m,ii] + self.alpha) \
            *(self.NZW[ii,n] + self.beta) \
            / (self.NZ[ii] + vsize * self.beta)
        
        p_z /= np.sum(p_z)

        return p_z

    def loglikelihood(self):
        """
        Desc: Compute the log likelihood that the model generated the data
        Input: self references
        Output: lik: float of the log likelihood
        """
        # Why are these being repeated here?
        vsize = self.matrix[m,:].nonzero()[0].size
        ndocs = self.NZM.shape[0]
        lik = 0

        for z in xrange(self.ntopics):
            lik += log_multi_beta(self.NZW[z,:] + self.beta)
            lik -= log_multi_beta(self.beta, vsize)

        for m in xrange(ndocs):
            lik += log_multi_beta(self.NZM[m,:] + self.alpha)
            lik -= log_multi_beta(self.alpha, self.ntopics)

        return lik

    def phi_theta(self):
        """
        Desc: Compute phi and theta, our topic by word probs and document by topic probs
        Input: Self references
        Output: Two arrays, holding
            [0] phi: Probability of topic by word
            [1] theta: Probability of document by topic
        """
        

        num_phi = self.NZW + self.beta
        num_phi /= np.sum(num_phi, axis = 0)[np.newaxis,:]

        num_theta = self.NZM + self.alpha
        num_theta /= np.sum(num_theta,axis = 1)[:,np.newaxis ]

        return num_phi, num_theta


    def run(self, maxiter = 30, burnin= 0):
        """
        Desc: Perform Gibbs sampling for maxiter iterations

        Input: matrix - An array that is a Document Term Frequency Matrix
               maxiter - An integer with the number of iterations
               Burnin - TBA: An integer of the number of burnins

        Output: phi_theta() Two arrays, holding
        [0] Probability of topic by word
        [1] Probability of document by topic
        """

        n_docs, vsize = self.matrix.shape
        topics2 = self.topics


        for iteration in xrange(maxiter + 2):
            # Idea: After each iteration we now want to
            # make assignments relative to the newly generated topics
            if iteration > 1:
                self.topics = topics2
            for m in xrange(n_docs):
                for n in xrange(vsize):
                    if self.matrix[m,n] == 0:
                        continue
                    for w in xrange(self.matrix[m,n]):
                        
                        z = self.topics[m,n]
                    
                        self.NZM[m,z] -= 1
                        self.NM[m] -= 1
                        self.NZW[z,n] -= 1
                        self.NZ[z] -= 1

                        p_z = self._conditional_distribution(m,n)
                        # Choosing a random topic row
                        ind_z = np.random.randint(self.ntopics)
                    
                        # Sampling random topic
                        z = index_sample(p_z)
                        
                        #Self.topics needs to change after we iterate over this word
                        # Otherwise at each iteration we subtract one from that space w*n times
                        # giving us a negative number
                        topics2[m,n] = z

                        self.NZM[m,z] += 1
                        self.NM[m] += 1
                        self.NZW[z,n] += 1
                        self.NZ[z] += 1

            if iteration > burnin:
                yield self.phi_theta()

                
    def runfort(self, maxiter = 30, burnin= 0):
        """
        Desc: Perform Gibbs sampling for maxiter iterations

        Input: matrix - An array that is a Document Term Frequency Matrix
               maxiter - An integer with the number of iterations
               Burnin - TBA: An integer of the number of burnins

        Output: phi_theta() Two arrays, holding
        [0] Probability of topic by word
        [1] Probability of document by topic
        """

        M,N = self.matrix.shape

        p_z = np.zeros(self.ntopics)
        p_z += 1./self.ntopics
        
 
        # Make everything fortan contiguous
        p_z=p_z.flatten() # Flatten array (Make 1-D)
        p_z=p_z.reshape(self.ntopics, order='F')
        run_matrix = np.array(self.matrix.transpose(),order='F')
        run_NZM = np.array(self.NZM.transpose(),order='F')
        run_NZW = np.array(self.NZW,order='F')
        run_NZ = np.array(self.NZ,order='F')
        run_NM = np.array(self.NM,order='F')
        # index starts at 1 in fortran
        run_topics = np.array(self.topics,order='F') + 1
        run_topics2 = run_topics
        
        
        topics2 = self.topics.transpose()
        loglik = np.zeros(maxiter)
        
        gibbsSampler6th.gibbs_sampler.gibbssampler(matrix = run_matrix,
                                                nzw = run_NZW,
                                                nzm = run_NZM,
                                                nz = run_NZ,
                                                nm = run_NM,
                                                max_iter = maxiter,
                                                p_z = p_z,
                                                m = M,
                                                n = N,
                                                topics = run_topics,
                                                alpha = self.alpha,
                                                beta = self.beta,
                                                lik = loglik)
                                                
        
        self.NZM = run_NZM.transpose()
        self.matrix = run_matrix.transpose()
        self.NZW = run_NZW
        self.NZ = run_NZ
        self.NM = run_NM

        #if iteration > burnin:
        return self.phi_theta(),loglik
                
                

    def prn(self,x = None):
        print x

    # For some reason this returns (maxiter - burnin) - 2 iterations?
    def update(self, maxiter = 20, burnin = 0):
        """
        Desc: Runs gibbs sampler for maxiter iterations
            Input: maxiter - integer specifying maximum number of iterations
                   burnin  - integer specifying number of iterations to burn through.
                                should be set to zero after initial burnin
            Output: phi_theta() Two arrays, holding
                [0] Probability of topic by word
                [1] Probability of document by topic
        """
        
        for iteration, phi_theta in enumerate(self.run( maxiter, burnin)):
            self.prn(iteration)
            self.prn(self.loglikelihood())
            self.logL.append(self.loglikelihood())
        return self.phi_theta(), self.logL

    def __call__(self):
        self.NZM = self.NZM
        self.NM = self.NM
        self.NZW = self.NZW
        self.NZ = self.NZ
        self.logL = self.logL
# Out:
# gibbssampler(matrix,nzw,nzm,nz,nm,p_z,topics,alpha,beta,lik,[ntopics,max_iter,m,n,top_size])
#
# Wrapper for ``gibbssampler``.
#
# Parameters
# ----------
# matrix : input rank-2 array('q') with bounds (n,m)
# nzw : input rank-2 array('q') with bounds (ntopics,n)
# nzm : input rank-2 array('q') with bounds (ntopics,m)
# nz : input rank-1 array('q') with bounds (ntopics)
# nm : input rank-1 array('q') with bounds (m)
# p_z : input rank-1 array('d') with bounds (ntopics)
# topics : input rank-1 array('q') with bounds (top_size)
# alpha : input float
# beta : input float
# lik : in/output rank-1 array('d') with bounds (max_iter)
#
# Other Parameters
# ----------------
# ntopics : input long, optional
#     Default: shape(nzw,0)
# max_iter : input long, optional
#     Default: len(lik)
# m : input long, optional
#     Default: shape(matrix,1)
# n : input long, optional
#     Default: shape(matrix,0)
# top_size : input long, optional
#     Default: len(topics)

# %%
# Little data for testing purposes
testing_frame = np.array([[1,0,4,2],[2,4,0,5]])
sampler = LdaSampler(data = testing_frame, ntopics = 4, alpha =.1,
                     beta = .1)

# %%
LDA_fort_test = sampler.runfort(maxiter=10000)

# %%
#
DIR = r'data_folder/wordcounts'
allfiles = glob.glob(os.path.join(DIR,"*.CSV"))
p=.2
# sample files for train
gen_sample = np.array(sorted(random.sample(xrange(len(allfiles)), int(p * len(allfiles)))))
rand_sample = [ allfiles[i] for i in gen_sample ]
#
# take rest for test
rand_sample2 = []
for i in xrange(len(allfiles)):
    if i not in gen_sample:
        rand_sample2.append(allfiles[i])
#
# train data

np_array_list = []
for file_ in rand_sample:
    df = pd.read_csv(file_,index_col=None, header=0)
    df['source'] = file_
    np_array_list.append(df.as_matrix())
#
# test data
np_array_list_test = []
for file_ in rand_sample2:
    df = pd.read_csv(file_, index_col = None, header = 0)
    df['source'] = file_
    np_array_list_test.append(df.as_matrix())
    
#
# train data frame
comb_np_array = np.vstack(np_array_list)
train_frame = pd.DataFrame(comb_np_array)
train_frame.columns = ['words','count','source']
subless = (train_frame['words'].str.len() > 2)
submore = (train_frame['words'].str.len() < 20)
train_frame = train_frame.loc[subless]
train_frame = train_frame.loc[submore]
train_frame = train_frame.fillna(value = 0)
train_frame = train_frame.pivot(index = 'source',columns = 'words', values = 'count')
train_frame = train_frame.fillna(value = 0)
train_frame = train_frame.loc[:, (train_frame.sum(axis = 0) > 10)]
#

# test data frame
comb_np_array_test = np.vstack(np_array_list_test)
test_frame = pd.DataFrame(comb_np_array_test)
test_frame.columns = ['words','count','source']
test_frame = test_frame.fillna(value=0)
test_frame = test_frame.pivot(index = 'source', columns = 'words', values = 'count')
test_frame = test_frame.fillna(value = 0)

train_frame1 = train_frame.values.astype(int)

# %%
citations = pd.read_csv("./data_folder/citations.tsv", sep="\t",index_col=False)

# %%
citations.to_csv("./Models/topics5/citations.csv")

# %%
train_frame.head()
# Out:
# words                                               abb  ability  able  about  \
# source
# data_folder/wordcounts/wordcounts_10.2307_22767...  0.0      0.0   0.0    2.0
# data_folder/wordcounts/wordcounts_10.2307_22768...  0.0      0.0   0.0    0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...  0.0      1.0   0.0    0.0
# data_folder/wordcounts/wordcounts_10.2307_22770...  0.0      1.0   0.0    4.0
# data_folder/wordcounts/wordcounts_10.2307_22770...  0.0      0.0   0.0    0.0
#
# words                                               above  absence  absolute  \
# source
# data_folder/wordcounts/wordcounts_10.2307_22767...    0.0      0.0       0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...    2.0      0.0       0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...    0.0      0.0       0.0
# data_folder/wordcounts/wordcounts_10.2307_22770...    0.0      0.0       0.0
# data_folder/wordcounts/wordcounts_10.2307_22770...    1.0      0.0       0.0
#
# words                                               abstract  academic  \
# source
# data_folder/wordcounts/wordcounts_10.2307_22767...       1.0       0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...       0.0       0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...       0.0       0.0
# data_folder/wordcounts/wordcounts_10.2307_22770...       0.0       0.0
# data_folder/wordcounts/wordcounts_10.2307_22770...       0.0       0.0
#
# words                                               academy ...   yobs  yohai  \
# source                                                      ...
# data_folder/wordcounts/wordcounts_10.2307_22767...      0.0 ...    0.0    0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...      1.0 ...    0.0    0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...      0.0 ...    0.0    0.0
# data_folder/wordcounts/wordcounts_10.2307_22770...      0.0 ...    0.0    0.0
# data_folder/wordcounts/wordcounts_10.2307_22770...      0.0 ...    0.0    0.0
#
# words                                               york  you  young  your  \
# source
# data_folder/wordcounts/wordcounts_10.2307_22767...   0.0  0.0    2.0   0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...   0.0  0.0    0.0   0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...   1.0  0.0    0.0   0.0
# data_folder/wordcounts/wordcounts_10.2307_22770...   0.0  6.0    0.0   4.0
# data_folder/wordcounts/wordcounts_10.2307_22770...   0.0  0.0    0.0   0.0
#
# words                                               youth  zeger  zero  zin
# source
# data_folder/wordcounts/wordcounts_10.2307_22767...    0.0    0.0   0.0  0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...    0.0    0.0   0.0  0.0
# data_folder/wordcounts/wordcounts_10.2307_22768...    0.0    0.0   0.0  0.0
# data_folder/wordcounts/wordcounts_10.2307_22770...    0.0    0.0   0.0  0.0
# data_folder/wordcounts/wordcounts_10.2307_22770...    0.0    0.0   0.0  0.0
#
# [5 rows x 3569 columns]

# %%
for i in xrange(10):
    print train_frame.index[i][34:49]
# Out:
# 10.2307_2276722
# 10.2307_2276818
# 10.2307_2276892
# 10.2307_2277014
# 10.2307_2277020
# 10.2307_2277078
# 10.2307_2277130
# 10.2307_2277258
# 10.2307_2277454
# 10.2307_2277672

# %%
citations
# Out:
#                    id               doi  \
# 0     10.2307/2287721   10.2307/2287721
# 1     10.2307/2286109   10.2307/2286109
# 2     10.2307/2287992   10.2307/2287992
# 3     10.2307/2284631   10.2307/2284631
# 4     10.2307/2288680   10.2307/2288680
# 5     10.2307/2291505   10.2307/2291505
# 6     10.2307/2291642   10.2307/2291642
# 7     10.2307/2282207   10.2307/2282207
# 8     10.2307/2283290   10.2307/2283290
# 9     10.2307/2281963   10.2307/2281963
# 10    10.2307/2282890   10.2307/2282890
# 11    10.2307/2282696   10.2307/2282696
# 12    10.2307/2289627   10.2307/2289627
# 13    10.2307/2278986   10.2307/2278986
# 14    10.2307/2279571   10.2307/2279571
# 15    10.2307/2289766   10.2307/2289766
# 16    10.2307/2291100   10.2307/2291100
# 17    10.2307/2283299   10.2307/2283299
# 18    10.2307/2286582   10.2307/2286582
# 19    10.2307/2282198   10.2307/2282198
# 20    10.2307/2286581   10.2307/2286581
# 21   10.2307/27639774  10.2307/27639774
# 22    10.2307/2288996   10.2307/2288996
# 23    10.2307/2288331   10.2307/2288331
# 24    10.2307/2287337   10.2307/2287337
# 25   10.2307/30047465  10.2307/30047465
# 26    10.2307/2281776   10.2307/2281776
# 27    10.2307/2285699   10.2307/2285699
# 28    10.2307/2669738   10.2307/2669738
# 29    10.2307/2287034   10.2307/2287034
# ..                ...               ...
# 970   10.2307/2281320   10.2307/2281320
# 971   10.2307/2669505   10.2307/2669505
# 972   10.2307/2287409   10.2307/2287409
# 973   10.2307/2281521   10.2307/2281521
# 974   10.2307/2278893   10.2307/2278893
# 975   10.2307/2280642   10.2307/2280642
# 976   10.2307/2279824   10.2307/2279824
# 977   10.2307/2282658   10.2307/2282658
# 978   10.2307/2669535   10.2307/2669535
# 979   10.2307/2281606   10.2307/2281606
# 980   10.2307/2282787   10.2307/2282787
# 981   10.2307/2290448   10.2307/2290448
# 982   10.2307/2280598   10.2307/2280598
# 983   10.2307/2286900   10.2307/2286900
# 984   10.2307/2289116   10.2307/2289116
# 985   10.2307/2290447   10.2307/2290447
# 986  10.2307/30047452  10.2307/30047452
# 987   10.2307/2283122   10.2307/2283122
# 988   10.2307/2289091   10.2307/2289091
# 989   10.2307/2281871   10.2307/2281871
# 990   10.2307/2287895   10.2307/2287895
# 991   10.2307/2287487   10.2307/2287487
# 992   10.2307/2285504   10.2307/2285504
# 993  10.2307/30045219  10.2307/30045219
# 994   10.2307/2278010   10.2307/2278010
# 995   10.2307/2286718   10.2307/2286718
# 996   10.2307/2287677   10.2307/2287677
# 997   10.2307/2284160   10.2307/2284160
# 998   10.2307/2283295   10.2307/2283295
# 999   10.2307/2277430   10.2307/2277430
#
#                                                  title  \
# 0                The Well-Calibrated Bayesian: Comment
# 1                                                  NaN
# 2    The Equivalence of Regression-Simple and Best-...
# 3    The Distribution by Age of the Frequency of Fi...
# 4                                                  NaN
# 5                                         Front Matter
# 6    On Variance Estimation With Imputed Survey Dat...
# 7    Problems Met by Companies that Instruct their ...
# 8                                  Notes About Authors
# 9    Notes on Immigration Statistics of the United ...
# 10                                                 NaN
# 11   The Metropolitan Area Concept: An Evaluation o...
# 12                                                 NaN
# 13                                                 NaN
# 14               The Construction of Two Height Charts
# 15   Multinomial Runs Tests to Detect Clustering in...
# 16                                                 NaN
# 17                                                 NaN
# 18   The Effect of Air Pollution Upon Mortality: A ...
# 19                                                 NaN
# 20   The Effect of Air Pollution Upon Mortality: A ...
# 21   A Monte Carlo Approach to Filtering for a Clas...
# 22   Multiplicative Errors-in-Variables Models with...
# 23   Dynamic Representation of Multivariate Time Se...
# 24                                                 NaN
# 25                                                 NaN
# 26   A Guide to the Literature on Statistics of Rel...
# 27                                                 NaN
# 28                                        Front Matter
# 29                              Asymmetric Time Series
# ..                                                 ...
# 970       Population Projections for Sales Forecasting
# 971                                                NaN
# 972  Explicit Estimators of Parametric Functions in...
# 973                                                NaN
# 974                                                NaN
# 975                                                NaN
# 976                                                NaN
# 977                                                NaN
# 978  REACT Scatterplot Smoothers: Superefficiency t...
# 979                                                NaN
# 980  Product Diversification and Living Costs: A Fu...
# 981  Alternative Estimates of the Effect of Family ...
# 982  Unemployment and Migration in the Depression (...
# 983                                   What Lies Ahead?
# 984                                        Back Matter
# 985  Measuring the Similarities Between the Lifetim...
# 986  Structural Break Estimation for Nonstationary ...
# 987                                                NaN
# 988                             [List of Book Reviews]
# 989                 On Noncoverage of Sample Dwellings
# 990         Frequency Polygons: Theory and Application
# 991                                                NaN
# 992  Permutation Tests Applied to Antibiotic Drug R...
# 993                                                NaN
# 994                                          Personals
# 995  Small-Sample Properties of Nonlinear Least Squ...
# 996  Asymptotic Properties of Classification Rules ...
# 997  Wilcoxon and t Test for Matched Pairs of Typed...
# 998                                                NaN
# 999      A Moving Secular Trend and Moving Integration
#
#                                                 author  \
# 0                                     Joseph B. Kadane
# 1                                      Andrew Sterrett
# 2                                      Luis A. Escobar
# 3                            A. J. Coale, D. R. McNeil
# 4                                          Roy Gardner
# 5                                                  NaN
# 6                                        Robert E. Fay
# 7                                    Theodore H. Brown
# 8                                                  NaN
# 9                                     E. P. Hutchinson
# 10                                     Gordon C. Bjork
# 11                                      Allan G. Feldt
# 12                                     Robert E. Weiss
# 13                                  Marion W. Worthing
# 14                                   May Ayres Burgess
# 15   Gail Rubin, Charles E. McCulloch, Michael A. S...
# 16                                     Frank B. Martin
# 17                                 Richard H. Lindeman
# 18                                 Byron W. Brown, Jr.
# 19                                     Werner Hochwald
# 20                                     Ronald E. Wyzga
# 21                      Silvia Centanni, Marco Minozzo
# 22                                      Jiunn T. Hwang
# 23        J. J. Mezrich, S. Frysinger, R. Slivjanovski
# 24                                       Diane Lambert
# 25                                          Anja Sturm
# 26                                    Benson Y. Landis
# 27                                   Samuel H. Preston
# 28                                                 NaN
# 29                                   William E. Wecker
# ..                                                 ...
# 970            Margaret Jarman Hagood, Jacob S. Siegel
# 971                              Robert L. Strawderman
# 972                                  A. Ronald Gallant
# 973                                  Howard W. Johnson
# 974                                     Melchior Palyi
# 975                                      Paul T. David
# 976                                   Frances V. Scott
# 977                                      Paul E. Smith
# 978                                       Rudolf Beran
# 979                                 Otis Dudley Duncan
# 980                                     Henry Anderson
# 981  Charles F. Manski, Gary D. Sandefur, Sara McLa...
# 982                    Ronald Freedman, Amos H. Hawley
# 983                               Franklin A. Graybill
# 984                                                NaN
# 985       Philip Hougaard, Bent Harvald, Niels V. Holm
# 986  Richard A. Davis, Thomas C. M. Lee, Gabriel A....
# 987                                     Emanuel Parzen
# 988                                                NaN
# 989                            Leslie Kish, Irene Hess
# 990                                     David W. Scott
# 991                                Patrick L. Brockett
# 992                        R. K. Tsutakawa, S. L. Yang
# 993                                    Ashish P. Sanil
# 994                                                NaN
# 995                                    John J. Spitzer
# 996                                    Kamal C. Chanda
# 997                   J. L. Hodges, Jr., E. L. Lehmann
# 998                                    E. Scott Maynes
# 999                                    Lincoln W. Hall
#
#                                         journaltitle  volume  issue  \
# 0    Journal of the American Statistical Association      77    379
# 1    Journal of the American Statistical Association      64    328
# 2    Journal of the American Statistical Association      81    393
# 3    Journal of the American Statistical Association      67    340
# 4    Journal of the American Statistical Association      78    382
# 5    Journal of the American Statistical Association      90    432
# 6    Journal of the American Statistical Association      91    434
# 7    Journal of the American Statistical Association      28    181
# 8    Journal of the American Statistical Association      58    302
# 9    Journal of the American Statistical Association      53    284
# 10   Journal of the American Statistical Association      59    305
# 11   Journal of the American Statistical Association      60    310
# 12   Journal of the American Statistical Association      85    412
# 13   Journal of the American Statistical Association      36    216
# 14   Journal of the American Statistical Association      32    198
# 15   Journal of the American Statistical Association      85    410
# 16   Journal of the American Statistical Association      90    430
# 17   Journal of the American Statistical Association      58    302
# 18   Journal of the American Statistical Association      73    363
# 19   Journal of the American Statistical Association      55    289
# 20   Journal of the American Statistical Association      73    363
# 21   Journal of the American Statistical Association     101    476
# 22   Journal of the American Statistical Association      81    395
# 23   Journal of the American Statistical Association      79    385
# 24   Journal of the American Statistical Association      77    380
# 25   Journal of the American Statistical Association     101    473
# 26   Journal of the American Statistical Association      54    286
# 27   Journal of the American Statistical Association      69    346
# 28   Journal of the American Statistical Association      95    452
# 29   Journal of the American Statistical Association      76    373
# ..                                               ...     ...    ...
# 970  Journal of the American Statistical Association      47    259
# 971  Journal of the American Statistical Association      95    451
# 972  Journal of the American Statistical Association      75    369
# 973  Journal of the American Statistical Association      51    276
# 974  Journal of the American Statistical Association      34    206
# 975  Journal of the American Statistical Association      39    228
# 976  Journal of the American Statistical Association      34    208
# 977  Journal of the American Statistical Association      59    308
# 978  Journal of the American Statistical Association      95    449
# 979  Journal of the American Statistical Association      55    292
# 980  Journal of the American Statistical Association      61    315
# 981  Journal of the American Statistical Association      87    417
# 982  Journal of the American Statistical Association      44    246
# 983  Journal of the American Statistical Association      72    357
# 984  Journal of the American Statistical Association      81    396
# 985  Journal of the American Statistical Association      87    417
# 986  Journal of the American Statistical Association     101    473
# 987  Journal of the American Statistical Association      59    307
# 988  Journal of the American Statistical Association      81    396
# 989  Journal of the American Statistical Association      53    282
# 990  Journal of the American Statistical Association      80    390
# 991  Journal of the American Statistical Association      75    370
# 992  Journal of the American Statistical Association      69    345
# 993  Journal of the American Statistical Association      98    461
# 994  Journal of the American Statistical Association      28    181
# 995  Journal of the American Statistical Association      74    365
# 996  Journal of the American Statistical Association      75    371
# 997  Journal of the American Statistical Association      68    341
# 998  Journal of the American Statistical Association      58    302
# 999  Journal of the American Statistical Association      20    149
#
#                   pubdate      pagerange                         publisher  \
# 0    1982-09-01T00:00:00Z    pp. 610-611  American Statistical Association
# 1    1969-12-01T00:00:00Z  pp. 1676-1677  American Statistical Association
# 2    1986-03-01T00:00:00Z    pp. 210-214  American Statistical Association
# 3    1972-12-01T00:00:00Z    pp. 743-749  American Statistical Association
# 4    1983-06-01T00:00:00Z         p. 502  American Statistical Association
# 5    1995-12-01T00:00:00Z            NaN  American Statistical Association
# 6    1996-06-01T00:00:00Z    pp. 517-519  American Statistical Association
# 7    1933-03-01T00:00:00Z      pp. 10-14  American Statistical Association
# 8    1963-06-01T00:00:00Z    pp. 538-540  American Statistical Association
# 9    1958-12-01T00:00:00Z   pp. 963-1025  American Statistical Association
# 10   1964-03-01T00:00:00Z    pp. 301-303  American Statistical Association
# 11   1965-06-01T00:00:00Z    pp. 617-636  American Statistical Association
# 12   1990-12-01T00:00:00Z  pp. 1172-1173  American Statistical Association
# 13   1941-12-01T00:00:00Z    pp. 566-568  American Statistical Association
# 14   1937-06-01T00:00:00Z    pp. 290-310  American Statistical Association
# 15   1990-06-01T00:00:00Z    pp. 315-320  American Statistical Association
# 16   1995-06-01T00:00:00Z    pp. 802-803  American Statistical Association
# 17   1963-06-01T00:00:00Z    pp. 576-577  American Statistical Association
# 18   1978-09-01T00:00:00Z         p. 472  American Statistical Association
# 19   1960-03-01T00:00:00Z    pp. 233-234  American Statistical Association
# 20   1978-09-01T00:00:00Z    pp. 463-472  American Statistical Association
# 21   2006-12-01T00:00:00Z  pp. 1582-1597  American Statistical Association
# 22   1986-09-01T00:00:00Z    pp. 680-688  American Statistical Association
# 23   1984-03-01T00:00:00Z      pp. 34-40  American Statistical Association
# 24   1982-12-01T00:00:00Z    pp. 938-939  American Statistical Association
# 25   2006-03-01T00:00:00Z         p. 388  American Statistical Association
# 26   1959-06-01T00:00:00Z    pp. 335-357  American Statistical Association
# 27   1974-06-01T00:00:00Z    pp. 574-575  American Statistical Association
# 28   2000-12-01T00:00:00Z        p. 1369  American Statistical Association
# 29   1981-03-01T00:00:00Z      pp. 16-21  American Statistical Association
# ..                    ...            ...                               ...
# 970  1952-09-01T00:00:00Z    pp. 524-540  American Statistical Association
# 971  2000-09-01T00:00:00Z        p. 1019  American Statistical Association
# 972  1980-03-01T00:00:00Z    pp. 182-193  American Statistical Association
# 973  1956-12-01T00:00:00Z    pp. 699-700  American Statistical Association
# 974  1939-06-01T00:00:00Z    pp. 455-456  American Statistical Association
# 975  1944-12-01T00:00:00Z         p. 534  American Statistical Association
# 976  1939-12-01T00:00:00Z    pp. 756-757  American Statistical Association
# 977  1964-12-01T00:00:00Z  pp. 1310-1311  American Statistical Association
# 978  2000-03-01T00:00:00Z    pp. 155-171  American Statistical Association
# 979  1960-12-01T00:00:00Z    pp. 757-758  American Statistical Association
# 980  1966-09-01T00:00:00Z    pp. 788-799  American Statistical Association
# 981  1992-03-01T00:00:00Z      pp. 25-37  American Statistical Association
# 982  1949-06-01T00:00:00Z    pp. 260-272  American Statistical Association
# 983  1977-03-01T00:00:00Z       pp. 7-10  American Statistical Association
# 984  1986-12-01T00:00:00Z  pp. 1133-1135  American Statistical Association
# 985  1992-03-01T00:00:00Z      pp. 17-24  American Statistical Association
# 986  2006-03-01T00:00:00Z    pp. 223-239  American Statistical Association
# 987  1964-09-01T00:00:00Z    pp. 973-974  American Statistical Association
# 988  1986-12-01T00:00:00Z        p. 1109  American Statistical Association
# 989  1958-06-01T00:00:00Z    pp. 509-524  American Statistical Association
# 990  1985-06-01T00:00:00Z    pp. 348-354  American Statistical Association
# 991  1980-06-01T00:00:00Z    pp. 473-474  American Statistical Association
# 992  1974-03-01T00:00:00Z      pp. 87-92  American Statistical Association
# 993  2003-03-01T00:00:00Z    pp. 252-253  American Statistical Association
# 994  1933-03-01T00:00:00Z         p. 100  American Statistical Association
# 995  1979-03-01T00:00:00Z      pp. 41-47  American Statistical Association
# 996  1980-09-01T00:00:00Z    pp. 726-728  American Statistical Association
# 997  1973-03-01T00:00:00Z    pp. 151-158  American Statistical Association
# 998  1963-06-01T00:00:00Z    pp. 569-572  American Statistical Association
# 999  1925-03-01T00:00:00Z      pp. 13-24  American Statistical Association
#
#     type                                      reviewed-work  \
# 0    fla                                                NaN
# 1    brv  Statistics for Mathematicians--An Introduction...
# 2    fla                                                NaN
# 3    fla                                                NaN
# 4    brv              Game Theory (2nd Ed.).|Guillermo Owen
# 5    mis                                                NaN
# 6    fla                                                NaN
# 7    fla                                                NaN
# 8    mis                                                NaN
# 9    fla                                                NaN
# 10   brv  Price and Quantity Trends in the Foreign Trade...
# 11   fla                                                NaN
# 12   brv  Handbook of Nonlinear Regression Models.|David...
# 13   brv  The Basing Point Problem., Price Discriminatio...
# 14   fla                                                NaN
# 15   fla                                                NaN
# 16   brv  Advanced Linear Models.|Song-Gui Wang;Shein-Ch...
# 17   brv  Statistics in Psychological Research.|William ...
# 18   fla                                                NaN
# 19   brv  Forecasting Economic Activity for the Chicago ...
# 20   fla                                                NaN
# 21   fla                                                NaN
# 22   fla                                                NaN
# 23   fla                                                NaN
# 24   brv  Asymptotic Efficiency of Statistical Estimator...
# 25   brv  The Theory of Measures and Integration|Eric M....
# 26   fla                                                NaN
# 27   brv  Differential Mortality in the United States: A...
# 28   mis                                                NaN
# 29   fla                                                NaN
# ..   ...                                                ...
# 970  fla                                                NaN
# 971  brv  Fast Reliable Algorithms for Matrices with Str...
# 972  fla                                                NaN
# 973  brv  Philadelphia Workers in a Changing Economy.|Gl...
# 974  brv  Die Deutsche Wirtschaftslage von 1914 bis 1923...
# 975  brv  The Geography of World Air Transport.|J. Parke...
# 976  brv  Committee of Statistical Experts, Report to th...
# 977  brv  Models of Income Determination.|National Burea...
# 978  fla                                                NaN
# 979  brv  The Fertility of American Women|Wilson H. Grab...
# 980  fla                                                NaN
# 981  fla                                                NaN
# 982  fla                                                NaN
# 983  fla                                                NaN
# 984  mis                                                NaN
# 985  fla                                                NaN
# 986  fla                                                NaN
# 987  brv  Smoothing, Forecasting and Prediction of Discr...
# 988  mis                                                NaN
# 989  fla                                                NaN
# 990  fla                                                NaN
# 991  brv  The Asymptotic Theory of Extreme Order Statist...
# 992  fla                                                NaN
# 993  brv  Principles of Data Mining|David Hand;Heikki Ma...
# 994  nws                                                NaN
# 995  fla                                                NaN
# 996  fla                                                NaN
# 997  fla                                                NaN
# 998  brv  Saving in India.|Nartional Council of Applied ...
# 999  fla                                                NaN
#
#                                               abstract
# 0                                                  NaN
# 1                                                  NaN
# 2    This article gives necessary and sufficient co...
# 3    The schedule recording first marriage frequenc...
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11   A selected group of 1950 SMA's are examined to...
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15   Psychologists often want to detect category st...
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20   The relationship between daily mortality and u...
# 21   Marked doubly stochastic Poisson processes are...
# 22   In an errors-in-variables model, the predictin...
# 23   In this article we describe a procedure for re...
# 24                                                 NaN
# 25                                                 NaN
# 26   The following bibliographic essay is a critica...
# 27                                                 NaN
# 28                                                 NaN
# 29   Asymmetric time series respond to innovations ...
# ..                                                 ...
# 970                                                NaN
# 971                                                NaN
# 972  When repetitive estimations are to be made und...
# 973                                                NaN
# 974                                                NaN
# 975                                                NaN
# 976                                                NaN
# 977                                                NaN
# 978  REACT estimators for the mean of a linear mode...
# 979                                                NaN
# 980  Two recent papers have pointed out that living...
# 981  Many studies have reported significant empiric...
# 982  This is a study of the reciprocal relationship...
# 983                                                NaN
# 984                                                NaN
# 985  The survival of like-sex twins born between 18...
# 986  This article considers the problem of modeling...
# 987                                                NaN
# 988                                                NaN
# 989  We present an investigation of the extent of n...
# 990  In this article I investigate the theoretical ...
# 991                                                NaN
# 992  Two multivariate forms of the permutation test...
# 993                                                NaN
# 994                                                NaN
# 995  Rao and Griliches (1969) compared several meth...
# 996  Suppose training samples are available from tw...
# 997  In paired comparisons of a treatment and contr...
# 998                                                NaN
# 999                                                NaN
#
# [1000 rows x 13 columns]

# %%
#sampler1 = LdaSampler(data = train_frame1, ntopics = 8, alpha = .0001, beta = .0001)

# %%
test_lda = sampler1.runfort( maxiter =3000, burnin = 0)

# %%
phi_theta = test_lda[0]
phi = pd.DataFrame(data=phi_theta[0], columns = train_frame.columns)
theta = pd.DataFrame(data=phi_theta[1])
dat_phi = phi.transpose()

# %%
import matplotlib.pyplot as plt
plt.plot(likelihood)
plt.ylabel('Negative Log Likelihood')
plt.show()

# %%
theta = pd.DataFrame(data=phi_theta[0], columns = train_frame.columns)
phi = pd.DataFrame(data=phi_theta[1])

# %%
theta
# Out:
# words       abb   ability      able     about     above   absence  absolute  \
# 0      0.052635  0.199999  0.195651  0.101370  0.137255  0.043481  0.214285
# 1      0.000005  0.066668  0.086957  0.131507  0.124183  0.130435  0.057144
# 2      0.210523  0.199999  0.130435  0.153425  0.156863  0.217388  0.085715
# 3      0.105264  0.066668  0.108696  0.109589  0.104575  0.217388  0.128571
# 4      0.105264  0.111111  0.086957  0.139726  0.137255  0.086958  0.171428
# 5      0.210523  0.111111  0.152173  0.123288  0.091503  0.086958  0.071429
# 6      0.105264  0.155555  0.108696  0.115069  0.130719  0.173911  0.185714
# 7      0.210523  0.088890  0.130435  0.126027  0.117647  0.043481  0.085715
#
# words  abstract  academic   academy    ...         yobs     yohai      york  \
# 0      0.000006  0.142857  0.233330    ...     0.119403  0.090912  0.145455
# 1      0.125000  0.085715  0.033336    ...     0.089553  0.181814  0.142857
# 2      0.249994  0.142857  0.133333    ...     0.104478  0.181814  0.109091
# 3      0.125000  0.114286  0.066668    ...     0.194029  0.090912  0.124675
# 4      0.187497  0.114286  0.233330    ...     0.149253  0.000009  0.109091
# 5      0.125000  0.199998  0.033336    ...     0.059702  0.090912  0.093507
# 6      0.125000  0.142857  0.133333    ...     0.119403  0.181814  0.145455
# 7      0.062503  0.057144  0.133333    ...     0.164179  0.181814  0.129870
#
# words       you     young      your     youth     zeger      zero       zin
# 0      0.107143  0.149999  0.027780  0.090912  0.083335  0.095478  0.000009
# 1      0.107143  0.050003  0.111111  0.090912  0.208331  0.100503  0.000009
# 2      0.125000  0.199997  0.166666  0.181814  0.166665  0.115578  0.090912
# 3      0.178571  0.100001  0.055557  0.090912  0.208331  0.145729  0.181814
# 4      0.125000  0.100001  0.166666  0.272717  0.166665  0.125628  0.181814
# 5      0.053572  0.149999  0.222220  0.181814  0.041669  0.110553  0.090912
# 6      0.232141  0.050003  0.138889  0.000009  0.000004  0.135678  0.181814
# 7      0.071429  0.199997  0.111111  0.090912  0.125000  0.170854  0.272717
#
# [8 rows x 3569 columns]

# %%
phi_new = pd.DataFrame(sampler1.NZW/np.sum( (sampler1.NZW + sampler1.beta),axis = 1)[:,np.newaxis],columns = train_frame.columns)
phi_new.to_csv("./Models/topics8/phi_new.csv")
phi.to_csv("./Models/topics8/phi.csv" )
theta.to_csv("./Models/topics8/theta.csv" )
pd.DataFrame(likelihood).to_csv("./Models/topics8/likelihood.csv" )
train_frame.to_csv("./Models/topics8/dtm_dat.csv" )

# %%
sampler2 = LdaSampler(data = train_frame1, ntopics = 20, alpha = .1, beta = .1)
test_lda2 = sampler2.runfort( maxiter =12000, burnin = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fdf6dced00a2> in <module>()
# ----> 1 sampler2 = LdaSampler(data = test_frame1, ntopics = 20, alpha = .1, beta = .1)
#       2 test_lda2 = sampler2.runfort( maxiter =12000, burnin = 0)
#
# NameError: name 'test_frame1' is not defined

# %%
sampler3 = LdaSampler(data = train_frame1, ntopics = 5, alpha = .1, beta = .1)
test_lda3 = sampler3.runfort( maxiter =12000, burnin = 0)

# %%
sampler4 = LdaSampler(data = train_frame1, ntopics = 30, alpha = .1, beta = .1)
test_lda4 = sampler4.runfort( maxiter =12000, burnin = 0)

# %%
test_lda3

# %%
# Grab made up data

import os
import shutil

N_TOPICS = 10
DOCUMENT_LENGTH = 100
FOLDER = "topicimg"

def vertical_topic(width, topic_index, document_length):
    """
    Generate a topic whose words form a vertical bar.
    """
    m = np.zeros((width, width))
    m[:, topic_index] = int(document_length / width)
    return m.flatten()

def horizontal_topic(width, topic_index, document_length):
    """
    Generate a topic whose words form a horizontal bar.
    """
    m = np.zeros((width, width))
    m[topic_index, :] = int(document_length / width)
    return m.flatten()

def save_document_image(filename, doc, zoom=2):
    """
    Save document as an image.
    doc must be a square matrix
    """
    height, width = doc.shape
    zoom = np.ones((width*zoom, width*zoom))
    # imsave scales pixels between 0 and 255 automatically
    sp.misc.imsave(filename, np.kron(doc, zoom))

def gen_word_distribution(ntopics, document_length):
    """
    Generate a word distribution for each of the ntopics.
    """
    width = ntopics / 2
    vsize = width ** 2
    m = np.zeros((ntopics, vsize))

    for k in range(width):
        m[k,:] = vertical_topic(width, k, document_length)

    for k in range(width):
        m[k+width,:] = horizontal_topic(width, k, document_length)

    m /= m.sum(axis=1)[:, np.newaxis] # turn counts into probabilities

    return m

def gen_document(word_dist, ntopics, vsize, length=DOCUMENT_LENGTH, alpha=0.1):
    """
    Generate a document:
    1) Sample topic proportions from the Dirichlet distribution.
    2) Sample a topic index from the Multinomial with the topic
       proportions from 1).
    3) Sample a word from the Multinomial corresponding to the topic
       index from 2).
    4) Go to 2) if need another word.
    """
    theta = np.random.mtrand.dirichlet([alpha] * ntopics)
    v = np.zeros(vsize)
    for n in range(length):
        z = index_sample(theta)
        w = index_sample(word_dist[z,:])
        v[w] += 1
    return v

def gen_documents(word_dist, ntopics, vsize, n=500):
    """
    Generate a document-term matrix.
    """
    m = np.zeros((n, vsize))
    for i in xrange(n):
        m[i, :] = gen_document(word_dist, ntopics, vsize)
    
    return m

if os.path.exists(FOLDER):
    shutil.rmtree(FOLDER)
os.mkdir(FOLDER)

width = N_TOPICS / 2
vocab_size = width ** 2
word_dist = gen_word_distribution(N_TOPICS, DOCUMENT_LENGTH)
matrix = gen_documents(word_dist, N_TOPICS, vocab_size)
